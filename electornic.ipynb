# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
fin = [100, 200, 300, 400, 500, 700, 900, 2000, 3000, 4000, 6000, 8000]
tmp = list(map(lambda x: math.log10(x), fin))
#print(len(fin))
Vout = [0.616, 1.14, 1.42, 1.68, 1.82, 1.93, 1.98, 1.74, 1.44, 1.22, 0.912, 0.736]
dt = [1.98, 0.76, 0.408, 0.236, 0.139, 0.0516, 0.026, -0.018, -0.036, -0.039, -0.035, -0.0284]# ms
dfa = []
for i in range(len(fin)):
    dfa.append(fin[i] * dt[i] *0.001 * 360 )
print(dfa)
# Out:
# [71.28, 54.72, 44.064, 33.984, 25.020000000000003, 13.0032, 8.424, -12.96, -38.879999999999995, -56.16, -75.60000000000001, -81.792]

# %% [markdown]
# dfa = -2pi/dt

# %%
plt.figure()
plt.plot(tmp, Vout, "-")

# %%
plt.figure()
plt.plot(tmp, dfa)
